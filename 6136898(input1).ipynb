# %%
import numpy as np

# %%
data_input = open('1_in.csv','r')
data = np.loadtxt(data_input,delimiter=",",dtype='int',skiprows = 1)

line = data[:,0]
data = (np.c_[data,np.zeros(len(line))]) 

for i in range(0,len(line)):
	data[i][3] = np.divide(data[i][2],data[i][1])

data_process = data[data[:,3].argsort()[::-1]]
data_sort = data_process[:,0].astype('int')
print(data_sort)
# Out:
# [ 609  494  619  194  641  480  616  367   15   17  897  668  265  565
#   834  690  673  208  461  587  299  956  169   12  296  328  435  735
#   824   56  868  712  463  291  451  711  988  310  770  594  855  292
#   331  852  888  983  438  309  397  416  623  683  437  356  442  708
#   974  577  863  777    9  813   89  244  559  307  302  657  531  137
#    40  660  534  418  651  984  736  447  841  516  880  877   31  524
#   945  817  930   65  669  614   88   68  231  506  592   93  576  570
#   186  688  659  938  421  854  844   39   37  876  384  252  979  658
#    92  959  444  595  230  768  950    3  638  628  833  593  696  301
#   303   16  692   22  350  677  722  462  324  260  126   67  721  493
#   398  108  320  695  114  257  893  643  579  911  542  617  600  929
#   370  273   74  468  701  429  670  687  903  917  597  713  958  799
#   591  747  488  238  664  507  889   71  942  317  436  951   73  233
# ...
